# %%
import torch

# %%
def format_actions(a: torch.Tensor) -> str:
    return "\n".join(tuple(", ".join(tuple(f"{x: 0.4f}" for x in r.tolist())) for r in a))

x = torch.randn(4,7)

s = format_actions(x)
print(s)
# Out:
# -1.9220, -1.0043, -0.4731,  0.7803,  1.4927, -0.4911,  0.4703
#  0.5812, -0.0443, -0.6253, -0.6272, -1.3680,  0.1480,  0.0735
# -0.3419,  0.0076,  0.5630, -0.0505,  0.1238, -0.1267, -1.6009
# -0.9516,  0.0887,  0.3869,  0.5204, -0.7599,  0.5890,  0.2330
